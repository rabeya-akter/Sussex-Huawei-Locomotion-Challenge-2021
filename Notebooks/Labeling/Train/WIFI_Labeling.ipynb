# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
WiFi=pd.read_csv("/content/drive/MyDrive/SHL 2021/Train/WiFi/WiFi_Final.csv", low_memory=False)

# %%
WiFi.drop(["I1","I2"],axis=1,inplace=True)

# %%
WiFi.head(3)
# Out:
#    Epoch time[ms]   N                 B1         S1  ...  S133  R133 F133 C133
# 0   1490430923358  10  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN  NaN
# 1   1490430924361  10  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN  NaN
# 2   1490430925365  10  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN  NaN
#
# [3 rows x 667 columns]

# %%
Label=pd.read_csv("/content/drive/MyDrive/SHL 2021/Train/Label/Label.csv",low_memory=False)

# %%
Label.head()
# Out:
#    Epoch time[ms]  Label
# 0   1490431583000      4
# 1   1490431584000      4
# 2   1490431585000      4
# 3   1490431586000      4
# 4   1490431587000      4

# %%
len(Label)
# Out:
# 980527

# %%
WiFi["Label"]=-1

# %%
WiFi.head()
# Out:
#    Epoch time[ms]   N                 B1         S1  ...  R133  F133 C133 Label
# 0   1490430923358  10  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN    -1
# 1   1490430924361  10  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN    -1
# 2   1490430925365  10  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN    -1
# 3   1490430926370  10  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN    -1
# 4   1490430927374  10  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN    -1
#
# [5 rows x 668 columns]

# %%
flag=0
for i in range(len(Label)-1):
  print(i, flag)
  for j in range(flag,len(WiFi)):
    print(j)
    if (WiFi["Epoch time[ms]"][j]>=int(Label["Epoch time[ms]"][i]) and WiFi["Epoch time[ms]"][j]<int(Label["Epoch time[ms]"][i+1])):
      WiFi.loc[j, 'Label']=Label["Label"][i]
      flag=j+1
      break
    elif WiFi["Epoch time[ms]"][j]>int(Label["Epoch time[ms]"][i+1]):
      break

# %%
WiFi["Label"].value_counts()
# Out:
# -1    494682
#  5    156011
#  7    153810
#  6    139387
#  2    120779
#  1    120167
#  8    117305
#  4    115585
#  3     41625
# Name: Label, dtype: int64

# %%
Final_WiFi=WiFi[WiFi['Label']!=-1]

# %%
Final_WiFi.head()
# Out:
#      Epoch time[ms]  N                 B1         S1  ...  R133  F133 C133 Label
# 657   1490431583458  6  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN     4
# 658   1490431584461  6  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN     4
# 659   1490431585464  6  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN     4
# 660   1490431587132  6  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN     4
# 661   1490431588135  6  c0:05:c2:29:40:ff  VM8236218  ...   NaN   NaN  NaN     4
#
# [5 rows x 668 columns]

# %%
Final_WiFi.tail()
# Out:
#          Epoch time[ms]  N                 B1  ... F133  C133  Label
# 1458747   1499267847339  5  52:0d:10:1a:29:49  ...  NaN   NaN      5
# 1458748   1499267848359  5  52:0d:10:1a:29:49  ...  NaN   NaN      5
# 1458749   1499267849366  5  52:0d:10:1a:29:49  ...  NaN   NaN      5
# 1458750   1499267850373  5  52:0d:10:1a:29:49  ...  NaN   NaN      5
# 1458751   1499267851386  5  52:0d:10:1a:29:49  ...  NaN   NaN      5
#
# [5 rows x 668 columns]

# %%
Final_WiFi.to_csv("/content/drive/MyDrive/SHL 2021/Train/WiFi/WiFi with Label.csv",index=False)
