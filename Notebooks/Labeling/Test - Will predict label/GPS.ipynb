# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GPS=pd.read_csv("/content/drive/MyDrive/SHL 2021/Test/GPS/GPS.csv", low_memory=False)
GPS['ache=1+nai=0']=0
GPS.head()
# Out:
#    Epoch time[ms]       Ignore1       Ignore2  ...  Elevation22  N  ache=1+nai=0
# 0   2496835043105  757837696635  120570372255  ...          NaN  0             0
# 1   2496835044023  758755279968  120570372255  ...          NaN  0             0
# 2   2496835045031  759763572676  120570372255  ...          NaN  0             0
# 3   2496835046029  760761237259  120570372255  ...          NaN  1             0
# 4   2496835047032  761764276322  120570372255  ...          NaN  1             0
#
# [5 rows x 93 columns]

# %%
Label=pd.read_csv("/content/drive/MyDrive/SHL 2021/Test/Label/Label.csv",low_memory=False)
Label.head()
# Out:
#    Epoch time[ms]
# 0   2496835247000
# 1   2496835248000
# 2   2496835249000
# 3   2496835250000
# 4   2496835251000

# %%
print(len(GPS))
print(len(Label))
# Out:
# 781773
# 671171

# %%
flag=0
for i in range(len(Label)-1):
  print(i, flag)
  for j in range(flag,len(GPS)):
    print(j)
    if (GPS["Epoch time[ms]"][j]>=int(Label["Epoch time[ms]"][i]) and GPS["Epoch time[ms]"][j]<int(Label["Epoch time[ms]"][i+1])):
      GPS.loc[j, 'ache=1+nai=0']=1
      flag=j+1
      break
    elif GPS["Epoch time[ms]"][j]>int(Label["Epoch time[ms]"][i+1]):
      break
# Out:
# Streaming output truncated to the last 5000 lines.
# 668865 778890
# 778890
# 668866 778891
# 778891
# 668867 778892
# 778892
# 668868 778893
# 778893
# 668869 778894
# 778894
# 668870 778895
# 778895
# 668871 778896
# 778896
# 668872 778897
# 778897
# 668873 778898
# 778898
# 668874 778899
# 778899
# 668875 778900
# 778900
# 668876 778901
# 778901
# 668877 778902
# 778902
# 668878 778903
# 778903
# 668879 778904
# 778904
# 668880 778905
# 778905
# 668881 778906
# 778906
# 668882 778907
# 778907
# 668883 778908
# 778908
# 668884 778909
# 778909
# 668885 778910
# 778910
# 668886 778911
# 778911
# 668887 778912
# 778912
# 668888 778913
# 778913
# 668889 778914
# 778914
# 668890 778915
# 778915
# 668891 778916
# 778916
# 668892 778917
# 778917
# 668893 778918
# 778918
# 668894 778919
# 778919
# 668895 778920
# 778920
# 668896 778921
# 778921
# 668897 778922
# 778922
# 668898 778923
# 778923
# 668899 778924
# 778924
# 668900 778925
# 778925
# 668901 778926
# 778926
# 668902 778927
# ...

# %%
GPS=GPS[GPS["ache=1+nai=0"]!=0]

# %%
GPS.to_csv("/content/drive/MyDrive/SHL 2021/Test/GPS/GPS- gonna give label.csv",index=False)
