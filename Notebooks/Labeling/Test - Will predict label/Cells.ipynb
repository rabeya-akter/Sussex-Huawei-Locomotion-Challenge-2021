# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cells=pd.read_csv("/content/drive/MyDrive/SHL 2021/Test/Cells/Cells_Final.csv", low_memory=False)
cells['ache=1+nai=0']=0
cells.head()
# Out:
#    Epoch time[ms]    N   L1  LREG1  ...  GASU7  GDBM7  GL7  ache=1+nai=0
# 0    2.496835e+12  1.0  LTE    1.0  ...    NaN    NaN  NaN             0
# 1    2.496835e+12  1.0  LTE    1.0  ...    NaN    NaN  NaN             0
# 2    2.496846e+12  1.0  LTE    1.0  ...    NaN    NaN  NaN             0
# 3    2.496846e+12  1.0  LTE    1.0  ...    NaN    NaN  NaN             0
# 4    2.496995e+12  1.0  LTE    1.0  ...    NaN    NaN  NaN             0
#
# [5 rows x 386 columns]

# %%
Label=pd.read_csv("/content/drive/MyDrive/SHL 2021/Test/Label/Label.csv",low_memory=False)
Label.head()
# Out:
#    Epoch time[ms]
# 0   2496835247000
# 1   2496835248000
# 2   2496835249000
# 3   2496835250000
# 4   2496835251000

# %%
print(len(cells))
print(len(Label))
# Out:
# 561369
# 671171

# %%
flag=0
for i in range(len(Label)-1):
  print(i, flag)
  for j in range(flag,len(cells)):
    print(j)
    if (cells["Epoch time[ms]"][j]>=int(Label["Epoch time[ms]"][i]) and cells["Epoch time[ms]"][j]<int(Label["Epoch time[ms]"][i+1])):
      cells.loc[j, 'ache=1+nai=0']=1
      flag=j+1
      break
    elif cells["Epoch time[ms]"][j]>int(Label["Epoch time[ms]"][i+1]):
      break
# Out:
# Streaming output truncated to the last 5000 lines.
# 668863 558537
# 558537
# 668864 558538
# 558538
# 668865 558539
# 558539
# 668866 558540
# 558540
# 668867 558541
# 558541
# 668868 558542
# 558542
# 668869 558543
# 558543
# 668870 558544
# 558544
# 668871 558545
# 558545
# 668872 558546
# 558546
# 668873 558547
# 558547
# 668874 558548
# 558548
# 668875 558549
# 558549
# 668876 558550
# 558550
# 668877 558551
# 558551
# 668878 558552
# 558552
# 668879 558553
# 558553
# 668880 558554
# 558554
# 668881 558555
# 558555
# 668882 558556
# 558556
# 668883 558557
# 558557
# 668884 558558
# 558558
# 668885 558559
# 558559
# 668886 558560
# 558560
# 668887 558561
# 558561
# 668888 558562
# 558562
# 668889 558563
# 558563
# 668890 558564
# 558564
# 668891 558565
# 558565
# 668892 558566
# 558566
# 668893 558567
# 558567
# 668894 558568
# 558568
# 668895 558569
# 558569
# 668896 558570
# 558570
# 668897 558571
# 558571
# 668898 558572
# 558572
# 668899 558572
# 558572
# 668900 558573
# ...

# %%
cells=cells[cells["ache=1+nai=0"]!=0]

# %%
cells.to_csv("/content/drive/MyDrive/SHL 2021/Test/Cells/Cells- gonna give label.csv",index=False)
