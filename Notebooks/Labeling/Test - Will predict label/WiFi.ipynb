# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
WiFi=pd.read_csv("/content/drive/MyDrive/SHL 2021/Test/WiFi/WiFi_Final.csv", low_memory=False)
WiFi.head(3)
# Out:
#    Epoch time[ms]            I1            I2  N  ... B173 S173  R173  F173
# 0   2496835042344  757077069552  120570372255  6  ...  NaN  NaN   NaN   NaN
# 1   2496835043348  758081201843  120570372255  6  ...  NaN  NaN   NaN   NaN
# 2   2496835044352  759084919031  120570372255  6  ...  NaN  NaN   NaN   NaN
#
# [3 rows x 869 columns]

# %%
Label=pd.read_csv("/content/drive/MyDrive/SHL 2021/Test/Label/Label.csv",low_memory=False)
Label.head()
# Out:
#    Epoch time[ms]
# 0   2496835247000
# 1   2496835248000
# 2   2496835249000
# 3   2496835250000
# 4   2496835251000

# %%
print(len(WiFi))
print(len(Label))
# Out:
# 771855
# 671171

# %%
WiFi.drop(["I1","I2"],axis=1,inplace=True)
WiFi["ache=1+nai=0"]=0

# %%
WiFi.head(2)
# Out:
#    Epoch time[ms]  N                 B1       S1  ...  S173  R173 F173 ache=1+nai=0
# 0   2496835042344  6  10:0d:7f:4d:0b:7c  wearlab  ...   NaN   NaN  NaN            0
# 1   2496835043348  6  10:0d:7f:4d:0b:7c  wearlab  ...   NaN   NaN  NaN            0
#
# [2 rows x 868 columns]

# %%
flag=0
for i in range(len(Label)-1):
  print(i, flag)
  for j in range(flag,len(WiFi)):
    print(j)
    if (WiFi["Epoch time[ms]"][j]>=int(Label["Epoch time[ms]"][i]) and WiFi["Epoch time[ms]"][j]<int(Label["Epoch time[ms]"][i+1])):
      WiFi.loc[j, 'ache=1+nai=0']=1
      flag=j+1
      break
    elif WiFi["Epoch time[ms]"][j]>int(Label["Epoch time[ms]"][i+1]):
      break
# Out:
# Streaming output truncated to the last 5000 lines.
# 769024
# 668865 769025
# 769025
# 668866 769026
# 769026
# 668867 769027
# 769027
# 668868 769028
# 769028
# 668869 769029
# 769029
# 668870 769030
# 769030
# 668871 769031
# 769031
# 668872 769032
# 769032
# 668873 769033
# 769033
# 668874 769034
# 769034
# 668875 769035
# 769035
# 668876 769036
# 769036
# 668877 769037
# 769037
# 668878 769038
# 769038
# 668879 769039
# 769039
# 668880 769040
# 769040
# 668881 769041
# 769041
# 668882 769042
# 769042
# 668883 769043
# 769043
# 668884 769044
# 769044
# 668885 769045
# 769045
# 668886 769046
# 769046
# 668887 769047
# 769047
# 668888 769048
# 769048
# 668889 769049
# 769049
# 668890 769050
# 769050
# 668891 769051
# 769051
# 668892 769052
# 769052
# 668893 769053
# 769053
# 668894 769054
# 769054
# 668895 769055
# 769055
# 668896 769056
# 769056
# 668897 769057
# 769057
# 668898 769057
# 769057
# 668899 769058
# 769058
# 668900 769059
# 769059
# 668901 769060
# 769060
# ...

# %%
wifi=WiFi[WiFi["ache=1+nai=0"]!=0]

# %%
wifi.head()
# Out:
#      Epoch time[ms]  N                 B1       S1  ...  S173  R173 F173 ache=1+nai=0
# 204   2496835247643  6  10:0d:7f:4d:0b:7c  wearlab  ...   NaN   NaN  NaN            1
# 205   2496835248646  6  10:0d:7f:4d:0b:7c  wearlab  ...   NaN   NaN  NaN            1
# 206   2496835249650  6  10:0d:7f:4d:0b:7c  wearlab  ...   NaN   NaN  NaN            1
# 207   2496835250654  6  10:0d:7f:4d:0b:7c  wearlab  ...   NaN   NaN  NaN            1
# 208   2496835251659  6  10:0d:7f:4d:0b:7c  wearlab  ...   NaN   NaN  NaN            1
#
# [5 rows x 868 columns]

# %%
wifi.to_csv("/content/drive/MyDrive/SHL 2021/Test/WiFi/WiFi- gonna give label.csv",index=False)
