# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Cells=pd.read_csv('/content/drive/MyDrive/SHL 2021/Validate/Cells/Cells_Final.csv',low_memory=False)
Cells.head()
# Out:
#    Epoch time[ms]    N   L1  LREG1  ...  GMNC7  GASU7  GDBM7  GL7
# 0    1.497426e+12  4.0  LTE    1.0  ...    NaN    NaN    NaN  NaN
# 1    1.497426e+12  4.0  LTE    1.0  ...    NaN    NaN    NaN  NaN
# 2    1.497426e+12  1.0  LTE    1.0  ...    NaN    NaN    NaN  NaN
# 3    1.497427e+12  4.0  LTE    1.0  ...    NaN    NaN    NaN  NaN
# 4    1.497427e+12  5.0  LTE    1.0  ...    NaN    NaN    NaN  NaN
#
# [5 rows x 335 columns]

# %%
Label=pd.read_csv("/content/drive/MyDrive/SHL 2021/Validate/Label/Label.csv",low_memory=False)
Label.head()
# Out:
#    Epoch time[ms]  Label
# 0   1497427493000      3
# 1   1497427494000      3
# 2   1497427495000      3
# 3   1497427496000      3
# 4   1497427497000      3

# %%
print(len(Cells))
print(len(Label))
# Out:
# 126333
# 143957

# %%
Cells["Label"]=-1

# %%
Cells.head()
# Out:
#    Epoch time[ms]    N   L1  LREG1  ...  GASU7  GDBM7  GL7  Label
# 0    1.497426e+12  4.0  LTE    1.0  ...    NaN    NaN  NaN     -1
# 1    1.497426e+12  4.0  LTE    1.0  ...    NaN    NaN  NaN     -1
# 2    1.497426e+12  1.0  LTE    1.0  ...    NaN    NaN  NaN     -1
# 3    1.497427e+12  4.0  LTE    1.0  ...    NaN    NaN  NaN     -1
# 4    1.497427e+12  5.0  LTE    1.0  ...    NaN    NaN  NaN     -1
#
# [5 rows x 336 columns]

# %%
flag=0
for i in range(len(Label)-1):
  print(i, flag)
  for j in range(flag,len(Cells)):
    print(j)
    if (Cells["Epoch time[ms]"][j]>=int(Label["Epoch time[ms]"][i]) and Cells["Epoch time[ms]"][j]<int(Label["Epoch time[ms]"][i+1])):
      Cells.loc[j, 'Label']=Label["Label"][i]
      flag=j+1
      break
    elif Cells["Epoch time[ms]"][j]>int(Label["Epoch time[ms]"][i+1]):
      break

# %%
Cells["Label"].value_counts()
# Out:
# -1    77834
#  5    15089
#  8    10429
#  7     7924
#  2     6680
#  1     6398
#  6     1970
#  4        9
# Name: Label, dtype: int64

# %%
Final_Cells=Cells[Cells["Label"]!=-1]

# %%
len(Final_Cells)
# Out:
# 48499

# %%
Final_Cells.to_csv("/content/drive/MyDrive/SHL 2021/Validate/Cells/Cells with Label.csv",index=False)
