# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GPS=pd.read_csv('/content/drive/MyDrive/SHL 2021/Validate/GPS/GPS.csv',low_memory=False)
GPS=GPS.drop(['Ignore1','Ignore2'],axis=1)
GPS.head()
# Out:
#    Epoch time[ms]    ID1  SNR1  Azimuth1  ...  SNR19  Azimuth19  Elevation19  N
# 0   1497426496525    NaN   NaN       NaN  ...    NaN        NaN          NaN  0
# 1   1497426497480    NaN   NaN       NaN  ...    NaN        NaN          NaN  0
# 2   1497426497900  168.0  27.0     109.0  ...    NaN        NaN          NaN  1
# 3   1497426498504   17.0  36.0      61.0  ...    NaN        NaN          NaN  2
# 4   1497426499510   15.0  22.0     179.0  ...    NaN        NaN          NaN  3
#
# [5 rows x 78 columns]

# %%
Label=pd.read_csv("/content/drive/MyDrive/SHL 2021/Validate/Label/Label.csv",low_memory=False)
Label.head()
# Out:
#    Epoch time[ms]  Label
# 0   1497427493000      3
# 1   1497427494000      3
# 2   1497427495000      3
# 3   1497427496000      3
# 4   1497427497000      3

# %%
print(len(GPS))
print(len(Label))
# Out:
# 157348
# 143957

# %%
GPS["Label"]=-1

# %%
GPS.head()
# Out:
#    Epoch time[ms]    ID1  SNR1  Azimuth1  ...  Azimuth19  Elevation19  N  Label
# 0   1497426496525    NaN   NaN       NaN  ...        NaN          NaN  0     -1
# 1   1497426497480    NaN   NaN       NaN  ...        NaN          NaN  0     -1
# 2   1497426497900  168.0  27.0     109.0  ...        NaN          NaN  1     -1
# 3   1497426498504   17.0  36.0      61.0  ...        NaN          NaN  2     -1
# 4   1497426499510   15.0  22.0     179.0  ...        NaN          NaN  3     -1
#
# [5 rows x 79 columns]

# %%
flag=0
for i in range(len(Label)-1):
  print(i, flag)
  for j in range(flag,len(GPS)):
    print(j)
    if (GPS["Epoch time[ms]"][j]>=int(Label["Epoch time[ms]"][i]) and GPS["Epoch time[ms]"][j]<int(Label["Epoch time[ms]"][i+1])):
      GPS.loc[j, 'Label']=Label["Label"][i]
      flag=j+1
      break
    elif GPS["Epoch time[ms]"][j]>int(Label["Epoch time[ms]"][i+1]):
      break
# Out:
# Streaming output truncated to the last 5000 lines.
# 141459 154757
# 154757
# 141460 154758
# 154758
# 141461 154759
# 154759
# 141462 154760
# 154760
# 141463 154761
# 154761
# 141464 154762
# 154762
# 141465 154763
# 154763
# 141466 154764
# 154764
# 141467 154765
# 154765
# 141468 154766
# 154766
# 141469 154767
# 154767
# 141470 154768
# 154768
# 141471 154769
# 154769
# 141472 154770
# 154770
# 141473 154771
# 154771
# 141474 154772
# 154772
# 141475 154773
# 154773
# 141476 154774
# 154774
# 141477 154775
# 154775
# 141478 154776
# 154776
# 141479 154777
# 154777
# 141480 154778
# 154778
# 141481 154779
# 154779
# 141482 154780
# 154780
# 141483 154781
# 154781
# 141484 154782
# 154782
# 141485 154783
# 154783
# 141486 154784
# 154784
# 141487 154785
# 154785
# 141488 154786
# 154786
# 141489 154787
# 154787
# 141490 154788
# 154788
# 141491 154789
# 154789
# 141492 154790
# 154790
# 141493 154791
# 154791
# 141494 154792
# 154792
# 141495 154793
# 154793
# 141496 154794
# ...

# %%
GPS["Label"].value_counts()
# Out:
# -1    73800
#  2    17913
#  1    14581
#  5    13899
#  7    12138
#  4    10783
#  8     9108
#  6     4212
#  3      914
# Name: Label, dtype: int64

# %%
Final_GPS=GPS[GPS["Label"]!=-1]

# %%
Final_GPS.to_csv("/content/drive/MyDrive/SHL 2021/Validate/GPS/GPS with Label.csv",index=False)
